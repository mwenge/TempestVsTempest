# %%
from PIL import Image,ImageDraw
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import numpy as np

# Create empty black canvas
im = Image.new('RGB', (92, 92))

# Draw red and yellow triangles on it and save
draw = ImageDraw.Draw(im)
vertices = [
    [(10,0), (50, 90), (90,90)],
]
for vertex in vertices:
    draw.polygon(vertex, fill = (255,0,0))

# Create figure and axes
fig, ax = plt.subplots()
# Display the image
ax.imshow(im)
plt.xticks([10,50,90]) 
plt.yticks([0,90]) 
plt.show()

# %%
# Create empty black canvas
im = Image.new('RGB', (180, 92))

# Draw red and yellow triangles on it and save
draw = ImageDraw.Draw(im)
vertices = [
    [(10,0), (50, 90), (90,90)],
    [(170,0), (130, 90), (90,90)],
]
for vertex in vertices:
    draw.polygon(vertex, fill = (255,0,0))

# Create figure and axes
fig, ax = plt.subplots()
# Display the image
ax.imshow(im)
plt.xticks([10,50,90,130,170]) 
plt.yticks([0,90]) 
plt.show()

# %%
# Create empty black canvas
im = Image.new('RGB', (180, 182))

# Draw red and yellow triangles on it and save
draw = ImageDraw.Draw(im)
vertices = [
    [(10,0), (50, 90), (90,90)],
    [(170,0), (130, 90), (90,90)],
    [(10,180), (50, 90), (90,90)],
    [(170,180), (130, 90), (90,90)],
]
for vertex in vertices:
    draw.polygon(vertex, fill = (255,0,0))

# Create figure and axes
fig, ax = plt.subplots()
# Display the image
ax.imshow(im)
plt.xticks([10,50,90,130,170]) 
plt.yticks([0,90,180]) 
plt.show()

# %%
from PIL import Image,ImageDraw

# Create empty black canvas
im = Image.new('RGB', (200, 200))

# Draw red and yellow triangles on it and save
draw = ImageDraw.Draw(im)
vertices = [
    [(10,0), (50, 90), (90,90)],
    [(170,0), (130, 90), (90,90)],
    [(10,180), (50, 90), (90,90)],
    [(170,180), (130, 90), (90,90)],
]
for vertex in vertices:
    draw.polygon(vertex, fill = (255,0,0))
im.resize((500, 500))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>
