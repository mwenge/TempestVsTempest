# %% [markdown]
# # Render Classic Tempest Vertex Objects

# %%
start = 0xf03a78
hex(0xf03bb2 - start)
# Out:
# '0x13a'

# %%
davesobj = 0x1ae148
0x1ae214 - davesobj
# Out:
# 204

# %%
matrix = 0x1d83f8
0x1d9bf8 - matrix
# Out:
# 6144

# %%
beasties = 0x1ae048
0x1ae114 - beasties
# Out:
# 204

# %%
384*2
# Out:
# 768

# %%
215040/4/384
# Out:
# 140.0

# %%
384*240*3
# Out:
# 276480

# %%
#Import libraries
import math
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
colors = {
    -1: "pink",
    0: "white",
    240: "red",
    143: "green",
    15: "yellow",
    255: "purple",
    136: "grey",
    128: "navy",
    43: "cyan"
}

def getVerticesAndConns(l, color="blue"):
    i = 0
    vertices = []
    while l[i]:
        x,y,z = l[i],l[i+1],l[i+2]
        i+=3
        conns = []
        while l[i]:
            if l[i] == -1:
                i+=1
                color = colors[l[i]]
            else:
                conns+=[(l[i],color)]
            i+=1
        vertices += [((x,y,z),conns)]
        i+=1
    return vertices

def plotObject(vertices):
    fig = plt.figure(figsize=(7,7))
    ax = plt.axes(projection='3d')
    ax.view_init(azim=135,elev=20,vertical_axis="y")
    ax.yaxis.set_inverted(True) 
    ax.xaxis.set_inverted(True) 
    ax.xaxis.set_pane_color("black")
    ax.yaxis.set_pane_color("black")
    ax.zaxis.set_pane_color("black")
    plt.rcParams['grid.color'] = "navy"

    for (x,y,z),conns in vertices:
        for conn,color in conns:
            x1,y1,z1 = vertices[conn-1][0]
            xs = np.array([[x,x1]])
            ys = np.array([[y,y1]])
            zs = np.array([[z,z1]])
            ax.plot_wireframe(xs,ys,zs,color=color)

# %% [markdown]
# ## Render the claws

# %%
claws = """
claw1:  dc.b 6,4,1,2,8,0
        dc.b 3,9,1,3,0
        dc.b 9,12,1,4,0
        dc.b 15,9,1,5,0
        dc.b 12,4,1,6,0
        dc.b 17,9,1,7,0
        dc.b 9,15,1,8,0
        dc.b 1,9,1,0,0

claw2:  dc.b 5,4,1,2,8,0
        dc.b 3,10,1,3,0
        dc.b 10,12,1,4,0
        dc.b 15,9,1,5,0
        dc.b 12,4,1,6,0
        dc.b 17,9,1,7,0
        dc.b 10,15,1,8,0
        dc.b 1,10,1,0,0

claw3:  dc.b 4,5,1,2,8,0
        dc.b 4,11,1,3,0
        dc.b 11,12,1,4,0
        dc.b 15,8,1,5,0
        dc.b 12,4,1,6,0
        dc.b 17,8,1,7,0
        dc.b 11,15,1,8,0
        dc.b 2,12,1,0,0

claw4:  dc.b 4,6,1,2,8,0
        dc.b 5,12,1,3,0
        dc.b 11,13,1,4,0
        dc.b 15,8,1,5,0
        dc.b 11,3,1,6,0
        dc.b 17,7,1,7,0
        dc.b 12,16,1,8,0
        dc.b 3,13,1,0,0

claw5:  dc.b 3,8,1,2,8,0
        dc.b 6,13,1,3,0
        dc.b 12,13,1,4,0
        dc.b 15,7,1,5,0
        dc.b 11,3,1,6,0
        dc.b 17,6,1,7,0
        dc.b 13,16,1,8,0
        dc.b 4,14,1,0,0

claw6:  dc.b 3,9,1,2,8,0
        dc.b 7,13,1,3,0
        dc.b 13,13,1,4,0
        dc.b 15,6,1,5,0
        dc.b 10,3,1,6,0
        dc.b 17,5,1,7,0
        dc.b 15,16,1,8,0
        dc.b 6,15,1,0,0

claw7:  dc.b 4,11,1,2,8,0
        dc.b 10,14,1,3,0
        dc.b 14,13,1,4,0
        dc.b 15,6,1,5,0
        dc.b 10,3,1,6,0
        dc.b 17,4,1,7,0
        dc.b 16,15,1,8,0
        dc.b 10,16,1,0,0

claw8:  dc.b 5,14,1,2,8,0
        dc.b 11,14,1,3,0
        dc.b 14,12,1,4,0
        dc.b 15,6,1,5,0
        dc.b 9,3,1,6,0
        dc.b 16,4,1,7,0
        dc.b 17,13,1,8,0
        dc.b 11,16,1,0,0
"""

d = claws
ls = [[int(x) for x in ','.join([x for x in p.split() if ',' in x]).split(',')]
     for p in d.split('\n\n')]
for l in ls:
    vertices = getVerticesAndConns(l,"yellow")
    plotObject(vertices)

# %% [markdown]
# ## Render the Tempest Title
# This is unused in the game.

# %%
tempest_title = """
tempest:dc.b 1,1,1,2,0
        dc.b 5,1,1,0
        dc.b 3,1,1,4,0
        dc.b 3,5,1,0
        dc.b 7,1,1,6,9,0
        dc.b 11,1,1,0
        dc.b 7,3,1,8,0
        dc.b 9,3,1,0
        dc.b 7,5,1,10,0
        dc.b 11,5,1,0
        dc.b 13,5,1,12,0
        dc.b 13,1,1,13,0
        dc.b 15,3,1,14,0
        dc.b 17,1,1,15,0
        dc.b 17,5,1,0
        dc.b 19,5,1,17,0
        dc.b 19,1,1,18,0
        dc.b 21,1,1,19,0
        dc.b 22,2,1,20,0
        dc.b 21,3,1,21,0
        dc.b 19,3,1,0
        dc.b 28,1,1,23,0
        dc.b 24,1,1,26,0
        dc.b 24,3,1,25,0
        dc.b 26,3,1,0
        dc.b 24,5,1,27,0
        dc.b 28,5,1,0
        dc.b 30,5,1,29,0
        dc.b 32,5,1,30,0
        dc.b 33,4,1,31,0
        dc.b 32,3,1,32,0
        dc.b 31,3,1,33,0
        dc.b 30,2,1,34,0
        dc.b 31,1,1,35,0
        dc.b 33,1,1,0
        dc.b 35,1,1,37,0
        dc.b 39,1,1,0
        dc.b 37,1,1,39,0
        dc.b 37,5,1,0,0
"""
d = tempest_title
l = [int(x) for x in ','.join([x for x in d.split() if ',' in x]).split(',')]
vertices = getVerticesAndConns(l)
plotObject(vertices)

# %% [markdown]
# ## Render a Cube

# %%
cube = """
cube:   dc.b 1,1,1,2,3,5,0
        dc.b 3,1,1,6,4,0
        dc.b 1,3,1,4,7,0
        dc.b 3,3,1,0
        dc.b 1,1,3,0
        dc.b 3,1,3,5,0
        dc.b 1,3,3,5,0
        dc.b 3,3,3,4,6,7,0,0
"""
d = cube
l = [int(x) for x in ','.join([x for x in d.split() if ',' in x]).split(',')]
vertices = getVerticesAndConns(l)
plotObject(vertices)

# %% [markdown]
# ##

# %%
enemies = """
shot:   dc.b 8,7,1,2,0
        dc.b 10,11,1,0
        dc.b 10,7,1,4,0
        dc.b 8,11,1,0
        dc.b 7,9,1,6,0
        dc.b 11,9,1,0,0

flipper:dc.b 2,5,1,2,6,0
        dc.b 16,13,1,3,0
        dc.b 12,9,1,4,0
        dc.b 16,5,1,5,0
        dc.b 2,13,1,6,0
        dc.b 6,9,1,0,0

zap:    dc.b 3,3,1,2,10,0
        dc.b 8,7,1,3,0
        dc.b 14,3,1,4,0
        dc.b 12,8,1,5,0
        dc.b 16,12,1,6,0
        dc.b 11,11,1,7,0
        dc.b 10,16,1,8,0
        dc.b 7,11,1,9,0
        dc.b 3,13,1,10,0
        dc.b 6,8,1,0,0

fliptank:
        dc.b 2,9,1,2,7,4,0
        dc.b 9,16,1,8,3,0
        dc.b 16,9,1,4,5,0
        dc.b 9,2,1,6,0
        dc.b 9,6,1,6,8,0
        dc.b 6,9,1,7,0
        dc.b 9,12,1,8,-1,240,0
        dc.b 12,9,1,0
        dc.b 7,8,1,10,14,-1,0,0
        dc.b 11,10,1,11,0
        dc.b 10,9,1,12,0
        dc.b 11,8,1,13,0
        dc.b 7,10,1,14,0
        dc.b 8,9,1,0,0

fusetank: dc.b 2,9,1,2,7,4,0
        dc.b 9,16,1,8,3,0
        dc.b 16,9,1,4,5,0
        dc.b 9,2,1,6,0
        dc.b 9,4,1,6,8,0
        dc.b 4,9,1,7,0
        dc.b 9,14,1,8,-1,240,0
        dc.b 14,9,1,0
        dc.b 9,9,1,10,0
        dc.b 8,10,1,11,0
        dc.b 8,12,1,0
        dc.b 10,11,1,-1,143,9,13,0
        dc.b 11,12,1,0
        dc.b 11,8,1,-1,240,9,15,0
        dc.b 12,8,1,0
        dc.b 8,7,1,-1,15,9,17,0
        dc.b 9,5,1,0
        dc.b 7,8,1,-1,255,9,19,0
        dc.b 5,9,1,0,0

pulstank: dc.b 2,9,1,2,7,4,0
        dc.b 9,16,1,8,3,0
        dc.b 16,9,1,4,5,0
        dc.b 9,2,1,6,0
        dc.b 9,4,1,6,8,0
        dc.b 4,9,1,7,0
        dc.b 9,14,1,8,-1,255,0
        dc.b 14,9,1,0
        dc.b 6,10,1,10,0
        dc.b 7,7,1,11,0
        dc.b 8,12,1,12,0
        dc.b 9,6,1,13,0
        dc.b 10,11,1,14,0
        dc.b 11,7,1,15,0
        dc.b 12,9,1,0,0

spike:
        dc.b 9,9,1,2,-1,136,0
        dc.b 9,9,2,0,0
        dc.b 9,9,3,0,0

spiker: dc.b 10,9,1,2,0
        dc.b 9,10,1,3,0
        dc.b 8,9,1,4,0
        dc.b 9,7,1,5,0
        dc.b 12,8,1,6,0
        dc.b 10,11,1,7,0
        dc.b 8,11,1,8,0
        dc.b 6,8,1,9,0
        dc.b 9,5,1,10,0
        dc.b 14,7,1,11,0
        dc.b 13,14,1,12,0
        dc.b 6,15,1,0,0
"""
d = enemies
ls = [[int(x) for x in ','.join([x for x in p.split() if ',' in x]).split(',')]
     for p in d.split('\n\n')]
for l in ls:
    vertices = getVerticesAndConns(l)
    plotObject(vertices)

# %% [markdown]
# ## Evitez las puntes (Avoid the Spikes)

# %%
evitez = """
ev:     dc.b 3,1,1,2,0
        dc.b 1,1,1,3,0
        dc.b 1,5,1,4,0
        dc.b 3,5,1,0
        dc.b 1,3,1,6,0
        dc.b 2,3,1,0
        dc.b 4,1,1,8,0
        dc.b 5,5,1,9,0
        dc.b 6,1,1,0
        dc.b 7,1,1,11,0
        dc.b 7,5,1,0
        dc.b 8,1,1,13,0
        dc.b 10,1,1,0
        dc.b 9,1,1,15,0
        dc.b 9,5,1,0
        dc.b 13,1,1,17,0
        dc.b 11,1,1,18,0
        dc.b 11,5,1,19,0
        dc.b 13,5,1,0
        dc.b 11,3,1,21,0
        dc.b 12,3,1,0
        dc.b 14,1,1,23,0
        dc.b 16,1,1,24,0
        dc.b 14,5,1,25,0
        dc.b 16,5,1,0,0

la_routine:
        dc.b 1,1,1,2,0
        dc.b 1,5,1,3,0
        dc.b 3,5,1,0
        dc.b 4,5,1,5,0
        dc.b 6,1,1,6,0
        dc.b 8,5,1,0
        dc.b 5,3,1,8,0
        dc.b 7,3,1,0
        dc.b 12,1,1,10,0
        dc.b 10,1,1,11,0
        dc.b 9,2,1,12,0
        dc.b 10,3,1,13,0
        dc.b 11,3,1,14,0
        dc.b 12,4,1,15,0
        dc.b 11,5,1,16,0
        dc.b 9,5,1,0,0

pu:     dc.b 1,5,1,2,0
        dc.b 1,1,1,3,0
        dc.b 3,1,1,4,0
        dc.b 4,2,1,5,0
        dc.b 3,3,1,6,0
        dc.b 1,3,1,0
        dc.b 5,1,1,8,0
        dc.b 5,4,1,9,0
        dc.b 6,5,1,10,0
        dc.b 7,5,1,11,0
        dc.b 8,4,1,12,0
        dc.b 8,1,1,0
        dc.b 9,5,1,14,0
        dc.b 9,1,1,15,0
        dc.b 11,5,1,16,0
        dc.b 11,1,1,0
        dc.b 12,1,1,18,0
        dc.b 14,1,1,0
        dc.b 13,1,1,20,0
        dc.b 13,5,1,0
        dc.b 17,1,1,22,0
        dc.b 15,1,1,23,0
        dc.b 15,5,1,24,0
        dc.b 17,5,1,0
        dc.b 15,3,1,26,0
        dc.b 16,3,1,0
        dc.b 21,1,1,28,0
        dc.b 19,1,1,29,0
        dc.b 18,2,1,30,0
        dc.b 19,3,1,31,0
        dc.b 20,3,1,32,0
        dc.b 21,4,1,33,0
        dc.b 20,5,1,34,0
        dc.b 18,5,1,0,0
"""

d = evitez
ls = [[int(x) for x in ','.join([x for x in p.split() if ',' in x]).split(',')]
     for p in d.split('\n\n')]
for l in ls:
    vertices = getVerticesAndConns(l)
    plotObject(vertices)

# %%
misc = """
fuse1:  dc.b 9,9,1,2,0
        dc.b 8,7,1,3,0
        dc.b 10,5,1,4,0
        dc.b 9,2,1,-1,-1,0
        dc.b 6,8,1,1,6,0
        dc.b 4,9,1,7,0
        dc.b 2,7,1,-1,128,0
        dc.b 7,12,1,1,9,0
        dc.b 7,14,1,10,0
        dc.b 5,16,1,-1,143,0
        dc.b 11,10,1,1,12,0
        dc.b 11,13,1,13,0
        dc.b 13,15,1,-1,240,0
        dc.b 11,7,1,1,15,0
        dc.b 13,7,1,16,0
        dc.b 14,5,1,0,0

fuse2:  dc.b 9,9,1,2,0
        dc.b 10,7,1,3,0
        dc.b 8,5,1,4,0
        dc.b 9,2,1,-1,-1,0
        dc.b 6,10,1,1,6,0
        dc.b 4,8,1,7,0
        dc.b 2,9,1,-1,128,0
        dc.b 8,13,1,1,9,0
        dc.b 6,13,1,10,0
        dc.b 5,16,1,-1,43,0
        dc.b 10,12,1,1,12,0
        dc.b 12,13,1,13,0
        dc.b 13,16,1,-1,240,0
        dc.b 13,8,1,1,15,0
        dc.b 13,6,1,16,0
        dc.b 15,4,1,0,0


b250:   dc.b 5,7,1,2,0
        dc.b 6,7,1,3,0
        dc.b 7,8,1,4,0
        dc.b 7,9,1,5,0
        dc.b 5,11,1,6,0
        dc.b 7,11,1,0
        dc.b 8,11,1,8,0
        dc.b 9,11,1,9,0
        dc.b 10,10,1,10,0
        dc.b 9,9,1,11,0
        dc.b 8,9,1,12,0
        dc.b 8,7,1,13,0
        dc.b 10,7,1,0
        dc.b 11,7,1,15,17,0
        dc.b 13,7,1,16,0
        dc.b 13,11,1,17,0
        dc.b 11,11,1,0,0

b500:   dc.b 7,7,1,2,0
        dc.b 5,7,1,3,0
        dc.b 5,9,1,4,0
        dc.b 6,9,1,5,0
        dc.b 7,10,1,6,0
        dc.b 6,11,1,7,0
        dc.b 5,11,1,0
        dc.b 8,7,1,9,11,0
        dc.b 10,7,1,10,0
        dc.b 10,11,1,11,0
        dc.b 8,11,1,0
        dc.b 11,7,1,13,15,0
        dc.b 13,7,1,14,0
        dc.b 13,11,1,15,0
        dc.b 11,11,1,0,0

b750:   dc.b 5,7,1,2,0
        dc.b 7,7,1,3,0
        dc.b 5,11,1,0
        dc.b 10,7,1,5,0
        dc.b 8,7,1,6,0
        dc.b 8,9,1,7,0
        dc.b 9,9,1,8,0
        dc.b 10,10,1,9,0
        dc.b 9,11,1,10,0
        dc.b 8,11,1,0
        dc.b 11,7,1,12,14,0
        dc.b 13,7,1,13,0
        dc.b 13,11,1,14,0
        dc.b 11,11,1,0,0

pu6:    dc.b 1,9,1,2,0
        dc.b 4,2,1,3,0
        dc.b 7,16,1,4,0
        dc.b 11,2,1,5,0
        dc.b 14,15,1,6,0
        dc.b 17,9,1,0,0

pu5:    dc.b 1,9,1,2,0
        dc.b 4,3,1,3,0
        dc.b 7,15,1,4,0
        dc.b 11,3,1,5,0
        dc.b 14,14,1,6,0
        dc.b 17,9,1,0,0

pu4:    dc.b 2,9,1,2,0
        dc.b 4,5,1,3,0
        dc.b 7,13,1,4,0
        dc.b 11,5,1,5,0
        dc.b 14,14,1,6,0
        dc.b 16,9,1,0,0

pu3:    dc.b 2,9,1,2,0
        dc.b 4,6,1,3,0
        dc.b 7,12,1,4,0
        dc.b 11,7,1,5,0
        dc.b 13,13,1,6,0
        dc.b 16,9,1,0,0

pu2:    dc.b 2,9,1,2,0
        dc.b 5,7,1,3,0
        dc.b 8,11,1,4,0
        dc.b 11,8,1,5,0
        dc.b 13,10,1,6,0
        dc.b 16,9,1,0,0

pu1:    dc.b 3,9,1,2,0
        dc.b 6,8,1,3,0
        dc.b 8,10,1,4,0
        dc.b 11,9,1,5,0
        dc.b 13,10,1,6,0
        dc.b 15,9,1,0,0

oneup:  dc.b 8,4,1,2,0
        dc.b 9,3,1,3,0
        dc.b 9,8,1,0
        dc.b 8,8,1,5,0
        dc.b 10,8,1,0
        dc.b 5,10,1,7,0
        dc.b 5,13,1,8,0
        dc.b 6,14,1,9,0
        dc.b 7,14,1,10,0
        dc.b 8,13,1,11,0
        dc.b 8,10,1,0
        dc.b 10,14,1,13,0
        dc.b 10,10,1,14,0
        dc.b 12,10,1,15,0
        dc.b 13,11,1,16,0
        dc.b 12,12,1,17,0
        dc.b 10,12,1,0,0

chevre: dc.b 9,5,1,2,0
        dc.b 9,9,7,3,0
        dc.b 9,13,1,0,0
"""

d = misc
ls = [[int(x) for x in ','.join([x for x in p.split() if ',' in x]).split(',')]
     for p in d.split('\n\n')]
for l in ls:
    vertices = getVerticesAndConns(l)
    plotObject(vertices)

# %%
test = """
t_test: dc.b 1,4,1,2,0
        dc.b 9,4,1,0
        dc.b 5,4,1,4,0
        dc.b 5,4,20,0,0

test:   dc.b 1,1,1,2,3,0
        dc.b 1,3,3,0
        dc.b 3,1,1,4,0
        dc.b 3,1,3,5,0
        dc.b 3,3,1,0,0
        dc.b 1,3,1,6,0
        dc.b 1,3,3,0
        dc.b 3,3,1,8,0
        dc.b 3,3,3,0,0

tetra:  dc.b 2,1,1,2,3,4,0
        dc.b 1,2,1,3,4,0
        dc.b 3,3,1,4,0
        dc.b 2,2,3,0,0
"""

d = test
ls = [[int(x) for x in ','.join([x for x in p.split() if ',' in x]).split(',')]
     for p in d.split('\n\n')]
for l in ls:
    vertices = getVerticesAndConns(l)
    plotObject(vertices)

# %%
from ascii_magic import AsciiArt
from PIL import Image

def fig2img(fig):
    """Convert a Matplotlib figure to a PIL Image and return it"""
    import io
    buf = io.BytesIO()
    fig.savefig(buf, transparent=True)
    buf.seek(0)
    img = Image.open(buf)
    return img

def plotAsciiObject(vertices,azim,elev):
    fig = plt.figure(figsize=(7,7))
    ax = plt.axes(projection='3d')
    ax.view_init(azim=azim,elev=elev,vertical_axis="y")
    ax.yaxis.set_inverted(True) 
    ax.xaxis.set_inverted(True) 
    ax.set_axis_off()
    ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    ax.yaxis.set_pane_color((1.0, 1.0, 1.0, 0.0))
    for (x,y,z),conns in vertices:
        for conn,color in conns:
            x1,y1,z1 = vertices[conn-1][0]
            xs = np.array([[x,x1]])
            ys = np.array([[y,y1]])
            zs = np.array([[z,z1]])
            ax.plot_wireframe(xs,ys,zs,color=color)
    return fig2img(fig)

def printAscii(d,cols=60,azim=180,elev=0):
    ascii_images = []
    ls = [[int(x) for x in ','.join([x for x in p.split() if ',' in x]).split(',')]
         for p in d.split('\n\n')]
    for l in ls:
        vertices = getVerticesAndConns(l,"yellow")
        im = plotAsciiObject(vertices,azim,elev)
        my_art = AsciiArt.from_pillow_image(im)
        ascii_images += [my_art.to_ascii(columns=cols, monochrome=True)]

    for i,ascii_image in enumerate(ascii_images):
        print(''.join(["; " + l +"\n" for l in ascii_image.splitlines()]))
        print('; ')

# %%
0x1c
# Out:
# 28

# %%
printAscii(claws)
# Out:
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                          $$        $$
# ;                        $$$$        $$$$$
# ;                      $$$$$           $$$$$
# ;                    $$$$$$             $$$$$$
# ;                   $$$$$$$             $$$$$$$
# ;                   $$$$$$$$$$$     $$$$$$$$$$$
# ;                      $$$$$$$$$$$$$$$$$$$$$
# ;                        $$$$$$$$$$$$$$$$
# ;                           $$$$$$$$$$$
# ;                              $$$$$
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
#
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                         $$         $$
# ;                        $$$         $$$$$
# ;                      $$$$            $$$$$
# ;                     $$$$              $$$$$$
# ;                   $$$$$$               $$$$$$
# ;                   $$$$$$$$$$       $$$$$$$$$$
# ;                    $$$$$$$$$$$$$$$$$$$$$$$
# ;                       $$$$$$$$$$$$$$$$$$
# ;                           $$$$$$$$$$$$
# ...

# %%
printAscii(tempest_title,cols=140)
# Out:
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                                            $$$$$$$  $$$$$$$$ $$    $$$ $$$$$  $$$$$$$$   $$$$$  $$$$$$$
# ;                                            $$$$$$$  $$$$$$$$ $$$   $$$ $$$$$  $$$$$$$$   $$$$$  $$$$$$$
# ;                                               $$    $$       $$$   $$$ $$ $$  $$         $$        $$
# ;                                               $$    $$       $$$   $$$ $$  $$ $$        $$$        $$
# ;                                               $$    $$       $$$$ $$$$ $$  $$ $$        $$         $$
# ;                                               $$    $$       $$$$ $$$$ $$  $$ $$        $$         $$
# ;                                               $$    $$       $$$$ $$$$ $$  $$ $$        $$         $$
# ;                                               $$    $$       $$$$$$ $$ $$  $$ $$        $$         $$
# ...

# %%
printAscii(cube,cols=80, azim=125,elev=20)
# Out:
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                                  $$$$$$$$$$
# ;                             $$$$$$$$$$$$$$$$$$$$$$$$$$
# ;                       $$$$$$$$$$$   $$      $$$$$$$$$$$$$$$$$$$$
# ;                  $$$$$$$$$$         $$                 $$$$$$$$$$$$$
# ;                $$$$$$$$$            $$                     $$$$$$$$$
# ;                $$$$$$$$$$$$$$$$$$$$ $$                $$$$$$$$$   $$
# ;                $$         $$$$$$$$$$$$$$$$$$$    $$$$$$$$$        $$
# ;                $$                  $$$$$$$$$$$$$$$$$$$            $$
# ;                $$                   $$       $$$$                 $$
# ;                 $$                  $$         $$                 $$
# ;                 $$                 $$$$$$      $$                 $$
# ;                 $$            $$$$$$$$$$$$$$$$$$$$               $$
# ;                 $$       $$$$$$$$$       $$$$$$$$$$$$$$$$$$      $$
# ...

# %%
printAscii(enemies,cols=100)
# Out:
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                                          $$                   $$
# ;                                          $$$                $$$$
# ;                                            $$$             $$$
# ;                                             $$$          $$$$
# ;                                              $$$$       $$$
# ;                                                $$$    $$$$
# ;                                                  $$$ $$$
# ;                                $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ;                                $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# ;                                                 $$$$ $$$
# ;                                                $$$    $$$$
# ;                                              $$$$       $$$
# ;                                             $$$          $$$$
# ;                                           $$$$             $$$
# ...

# %%
printAscii(misc,cols=100)
# Out:
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                                                        $$
# ;                                                        $$$
# ;                                                         $$$
# ;                                                          $$$            ss
# ;                                                       $$$$$$          ssss
# ;                               Qkk                  $$$$$$    ssssssssssss
# ;                               mkkkkkQ    mbAOkkA&&Q$$$$  ssssssssssssss
# ;                                  QAOAOYOOOkOAAYAAOkA&U&msss*s
# ;                                      AAkQ           l))*r{}{sr{s
# ;                                                   ''''      1crr
# ;                                                 ''''          r{
# ;                                                 ''            sr3
# ;                                                '''            }sssls
# ...

# %%
printAscii(evitez,cols=100)
# Out:
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                               $$$$$$$  $$   $$ $$ $$$$$$$ $$$$$$$$ $$$$$$$
# ;                               $$$$$$$  $$   $$ $$ $$$$$$$ $$$$$$$$ $$$$$$$
# ;                               $$       $$   $$ $$    $$   $$            $$
# ;                               $$       $$   $$ $$    $$   $$           $$
# ;                               $$       $$  $$$ $$    $$   $$           $$
# ;                               $$       $$$ $$  $$    $$   $$           $$
# ;                               $$        $$ $$  $$    $$   $$          $$
# ;                               $$$$$     $$ $$  $$    $$   $$$$$       $$
# ;                               $$$$$     $$ $$  $$    $$   $$$$$      $$$
# ;                               $$        $$ $$  $$    $$   $$         $$
# ;                               $$        $$$$   $$    $$   $$         $$
# ;                               $$         $$$   $$    $$   $$        $$
# ...

# %%
printAscii(test,cols=100, azim=125,elev=20)
# Out:
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                                  $$$$$$
# ;                                  $$$$$$$$$$$$$$$                                   $
# ;                                        $$$$$$$$$$$$$$$$$$                     $$$$$$
# ;                                                 $$$$$$$$$$$$$$$$$$$       $$$$$$$$$
# ;                                                           $$$$$$$$$$$$$$$$$$$$
# ;                                                                   $$$$$$$$
# ;                                                               $$$$$$$$
# ;                                                            $$$$$$$
# ;                                                            $$$
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
#
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;
# ;                                              $$$$$
# ;                                              $$$$$$$$$$$$$$$$
# ...
